# %%
import matplotlib.pyplot as plt
import numpy as np

def x1(n):
    return np.cos(0.3 * np.pi * n)

def x2(n):
    return np.cos(2.3 * np.pi * n)

n = np.linspace(0, 31, 1)

x1_n = x1(n)
x2_n = x2(n)
